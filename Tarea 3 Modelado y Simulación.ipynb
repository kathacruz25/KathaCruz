# %% [markdown]
# # Tarea 3#

# %% [markdown]
# ###### Katherine Marcela Cruz Cáceres 614191004

# %% [markdown]
# $1.$ De Apostol Vol. 2, elabore la gráfica de los compos vectoriales indicados en el numeral 1 de la sección de jercicos 8.14

# %% [markdown]
# ##### Solución

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.arange(-0.8, 2, 0.8),
                      np.arange(-0.8, 2, 0.8),
                      np.arange(-0.8, 2, 0.8))

u = 2*x+y**3*np.cos(x*y)
v = 2*y*np.sin(x*y)+x*y**2*np.cos(x*y)
w = 0

ax.quiver(x, y, z, u, v, w, length=0.1)

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.arange(-0.8, 2, 0.8),
                      np.arange(-0.8, 2, 0.8),
                      np.arange(-0.8, 2, 0.8))

u = np.e**x*np.cos(y)
v = -np.e**x*np.sin(y)
w = 0

ax.quiver(x, y, z, u, v, w, length=0.1)

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.arange(-0.8, 2, 0.8),
                      np.arange(-0.8, 2, 0.8),
                      np.arange(-0.8, 2, 0.8))

u = 2*x*y**3*z**4
v = 3*x**2*y**2*z**4
w = 4*x**2*y**3*z**3

ax.quiver(x, y, z, u, v, w, length=0.1)

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.arange(-0.8, 2, 0.8),
                      np.arange(-0.8, 2, 0.8),
                      np.arange(-0.8, 2, 0.8))

u = 2*x
v = -2*y
w = 4*z

ax.quiver(x, y, z, u, v, w, length=0.1)

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.arange(0.1, 3, 0.8),
                      np.arange(0.1, 3, 0.8),
                      np.arange(0.1, 3, 0.8))

u = (2*x)/(x**2+2*y**2-3*z**2)
v = (4*y)/((x**2+2*y**2-3*z**2))
w = (6*z)/((x**2+2*y**2-3*z**2))

ax.quiver(x, y, z, u, v, w, length=0.1)

plt.show()
# Out:
# C:\Users\aljea\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in true_divide
#   if sys.path[0] == '':
# C:\Users\aljea\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in true_divide
#   del sys.path[0]
# C:\Users\aljea\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in true_divide
#
# C:\Users\aljea\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2721: RuntimeWarning: invalid value encountered in multiply
#   shafts = (XYZ - np.multiply.outer(shaft_dt, UVW)).swapaxes(0, 1)
# C:\Users\aljea\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2640: RuntimeWarning: invalid value encountered in double_scalars
#   x = uvw[1] / norm
# C:\Users\aljea\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2641: RuntimeWarning: invalid value encountered in double_scalars
#   y = -uvw[0] / norm

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.arange(0.1, 2, 0.8),
                      np.arange(0.1, 2, 0.8),
                      np.arange(0.1, 2, 0.8))

u = y**z*x**(y**z-1)
v = x**(y**z)*np.log(x)*z*y**(z-1)
w = x**(y**z)*np.log(x)*y**(z)*np.log(y)

ax.quiver(x, y, z, u, v, w, length=0.1)

plt.show()

# %% [markdown]
# $2.$ De Apostol Vol. 2, elabore el ejercicio 4 indicado en  la sección de jercicos 8.17

# %% [markdown]
# #### Solución

# %% [markdown]
# $a)$
# El vector gradiente $\nabla{z}$ siempre es normal a cada curva de la superficie.
#
# Si $$z = \sqrt{x^2+y^2}+(x^2+y^2)^\frac{3}{2}$$
#
# Entonces por un lado tenemos que la derivada parcial de $z$ respecto a $x$ es
#
# $$\frac{\partial{}}{\partial{x}}\sqrt{x^2+y^2}+(x^2+y^2)^\frac{3}{2} = \frac{\partial{}}{\partial{x}}\sqrt{x^2+y^2} + \frac{\partial{}}{\partial{x}}(x^2+y^2)^\frac{3}{2}$$
#
# $$= x(x^2+y^2)^\frac{-1}{2} + x(x^2+y^2)^\frac{3}{2}$$
#
# $$= x\left((x^2+y^2)^\frac{-1}{2} + (x^2+y^2)^\frac{3}{2}\right)$$
#
# <span style = "color:red">$$= \frac{3x^3 + 3xy^2 + x}{\sqrt{x^2+y^2}}$$
#
# La derivada parcial respecto a $y$ sera similar a la de $x$
#
#
# $$\frac{\partial{}}{\partial{y}}\sqrt{x^2+y^2}+(x^2+y^2)^\frac{3}{2} = \frac{\partial{}}{\partial{y}}\sqrt{x^2+y^2} + \frac{\partial{}}{\partial{y}}(x^2+y^2)^\frac{3}{2}$$
#
# $$= y(x^2+y^2)^\frac{-1}{2} + y(x^2+y^2)^\frac{3}{2}$$
#
# $$= y\left((x^2+y^2)^\frac{-1}{2} + (x^2+y^2)^\frac{3}{2}\right)$$
#
# <span style = "color:red">$$= \frac{3yx^2 + 3y^3 + y}{\sqrt{x^2+y^2}}$$
#
# Para la derivada parcial respecto a $z$ tenemos que va a ser igual a cero. Entnces el vector normal a la superficie es
#
# $$V(x,y,z) = \left(\frac{3x^3 + 3xy^2 + x}{\sqrt{x^2+y^2}},\frac{3yx^2 + 3y^3 + y}{\sqrt{x^2+y^2}},0\right)$$
#
#
#
# $b)$ Para hallar el $\cos{(\theta)}$, donde $\theta$ es el angulo comprendido entre el vector normal y el eje $z$, hay que recordad que $\vec{a}\centerdot\vec{b} = ||\vec{a}|| \centerdot ||\vec{b}||\cos{(\theta)}$
# Teniendo en cuenta que el eje $z$ tiene como coordenadas $(0,0,1)$
# $$\vec{z}\centerdot V(x,y,z) = 0$$
#
# Entonces
# $$||\vec{a}|| \centerdot ||\vec{b}||\cos{(\theta)} = 0$$
#
# Como la mutiplicacion de las normas es una constante distinta de 0, esto quiere decir que al dividir sobre estas se tiene que $$\cos{(\theta)} = 0$$

# %% [markdown]
# $3.$ De Apostol Vol. 2, sección de jercicos 8.22. Desarrolle los ejercicos 13 y 14

# %% [markdown]
# ##### Solución

# %% [markdown]
# $13.a.$ Si $f(x,y,z) = xi + yj + zk$ entonces la matriz Jacobiana $Df(x,y,z)$ es
#
# $$\begin{pmatrix}
# \frac{\partial{f_x}}{\partial{x}} & \frac{\partial{f_x}}{\partial{y}} & \frac{\partial{f_x}}{\partial{z}} \\
# \frac{\partial{f_y}}{\partial{x}} & \frac{\partial{f_y}}{\partial{y}} & \frac{\partial{f_y}}{\partial{z}}  \\
# \frac{\partial{f_z}}{\partial{x}} & \frac{\partial{f_z}}{\partial{y}} & \frac{\partial{f_z}}{\partial{z}}  \\
# \end{pmatrix} =
# \begin{pmatrix}
# \frac{\partial{xi}}{\partial{x}} & \frac{\partial{xi}}{\partial{y}} & \frac{\partial{xi}}{\partial{z}} \\
# \frac{\partial{yj}}{\partial{x}} & \frac{\partial{yj}}{\partial{y}} & \frac{\partial{yj}}{\partial{z}}  \\
# \frac{\partial{zk}}{\partial{x}} & \frac{\partial{zk}}{\partial{y}} & \frac{\partial{zk}}{\partial{z}}  \\
# \end{pmatrix} =
# \begin{pmatrix}
# 1 & 0 & 0 \\
# 0 & 1 & 0 \\
# 0 & 0 & 1 \\
# \end{pmatrix}$$
#
# $13.b.$ Seran Todos los campos de la forma $f(x,y,z) = xi + yj + zk$ mas un vector constante
#
# $13.c.$ Los campos vectoriales son de la forma $f(x,y,z) = P(x)i + Q(y)j + R(z)k $ donde las funciones cumplen que $P(x) = n, Q(y) = m $ y $ R(z) = l$ con $n, m, l \in \mathbb{R}$.
#
# $14.a.$ Si
# $$f(x,y) = e^{x+2y} + \sin{(y + 2x)}$$
# $$g(u,v,w) = (u + 2v^2 + 3w^3) + (2v - u^2)$$
#
# Entonces
#
# $$Df(x,y) =
# \begin{pmatrix}
# \frac{\partial{f_x}}{\partial{x}} & \frac{\partial{f_x}}{\partial{y}} \\
# \frac{\partial{f_y}}{\partial{x}} & \frac{\partial{f_y}}{\partial{y}} \\
# \end{pmatrix} =
# \begin{pmatrix}
# \frac{\partial}{\partial{x}}{e^{x+2y}} & \frac{\partial}{\partial{y}}{e^{x+2y}}  \\
# \frac{\partial}{\partial{x}}{\sin{(y + 2x)}} & \frac{\partial}{\partial{y}}{\sin{(y + 2x)}} \\
# \end{pmatrix} =
# \begin{pmatrix}
# e^{x+2y} & 2e^{x+2y} \\
# 2\cos{(2x+y)} & \cos{(2x+y)} \\
# \end{pmatrix}
# $$
#
# $$Dg(u,v,w) =
# \begin{pmatrix}
# \frac{\partial{g_u}}{\partial{u}} & \frac{\partial{g_u}}{\partial{v}} & \frac{\partial{g_u}}{\partial{w}}\\
# \frac{\partial{g_v}}{\partial{u}} & \frac{\partial{g_v}}{\partial{v}} & \frac{\partial{g_v}}{\partial{w}}\\
# \frac{\partial{g_w}}{\partial{u}} & \frac{\partial{g_w}}{\partial{v}} & \frac{\partial{g_w}}{\partial{w}}\\
# \end{pmatrix} =
# \begin{pmatrix}
# \frac{\partial}{\partial{u}}{(u + 2v^2 + 3w^3)} & \frac{\partial}{\partial{v}}{(u + 2v^2 + 3w^3)} & \frac{\partial}{\partial{w}}{(u + 2v^2 + 3w^3)} \\
# \frac{\partial}{\partial{u}}{(2v - u^2)} & \frac{\partial}{\partial{v}}{(2v - u^2)} & \frac{\partial}{\partial{w}}{(2v - u^2)}\\
# 0 & 0 & 0 \\
# \end{pmatrix} =
# \begin{pmatrix}
# 1 & 4v & 9w^2 \\
# -2u & 2 & 0\\
# 0 & 0 & 0 \\
# \end{pmatrix}
# $$
#
# $14.b.$ La composicion $h(u,v,w) = f[g(u,v,w)]$ es
#
# $$h(u,v,w) = e^{(u + 2v^2 + 3w^3)+2(2v - u^2)} + \sin{((2v - u^2) + 2(u + 2v^2 + 3w^3))}$$
#
# $14.c.$ La matriz Jacobiana de $h(u,v,w)$ es
#
# $$Dh(u,v,w) =
# \begin{pmatrix}
# \frac{\partial{h_u}}{\partial{u}} & \frac{\partial{h_u}}{\partial{v}} & \frac{\partial{h_u}}{\partial{w}}\\
# \frac{\partial{h_v}}{\partial{u}} & \frac{\partial{h_v}}{\partial{v}} & \frac{\partial{h_v}}{\partial{w}}\\
# \frac{\partial{h_w}}{\partial{u}} & \frac{\partial{h_w}}{\partial{v}} & \frac{\partial{h_w}}{\partial{w}}\\
# \end{pmatrix} =
# $$
#
# $$
# \begin{pmatrix}
# \frac{\partial}{\partial{u}}e^{(u + 2v^2 + 3w^3)+2(2v - u^2)} & \frac{\partial}{\partial{v}}e^{(u + 2v^2 + 3w^3)+2(2v - u^2)} & \frac{\partial}{\partial{w}}e^{(u + 2v^2 + 3w^3)+2(2v - u^2)}\\
# \frac{\partial}{\partial{u}}\sin{((2v - u^2) + 2(u + 2v^2 + 3w^3))} & \frac{\partial}{\partial{v}}\sin{((2v - u^2) + 2(u + 2v^2 + 3w^3))} & \frac{\partial}{\partial{w}}\sin{((2v - u^2) + 2(u + 2v^2 + 3w^3))}\\
# \frac{\partial}{\partial{u}} & \frac{\partial}{\partial{v}} & \frac{\partial}{\partial{w}}\\
# \end{pmatrix} =
# $$
#
# $$
# \begin{pmatrix}
# (1-4u)e^(-2u^2+u+2v^2+4v+3w^3) & 4(v+1)e^(-2u^2+u+2v^2+4v+3w^3) & 9w^2e^(-2u^2+u+2v^2+4v+3w^3)\\
# -2(u-1)\cos{(-u^2+2u+4v^2+2v+6w^3)} & 2(4v+1)\cos{(-u^2+2u+4v^2+2v+6w^3)} & 18w^2\cos{(-u^2+2u+4v^2+2v+6w^3)}\\
# 0 & 0 & 0 \\
# \end{pmatrix}
# $$
#
# $$Dh(1,-1,1) =
# \begin{pmatrix}
# -3 & 0 & 9 \\
# 0 & -6\cos{(9)} & 18\cos{(9)}\\
# 0 & 0 & 0 \\
# \end{pmatrix}
# $$

# %% [markdown]
# $4.$ De Apostol Vol. 2, sección de jercicos 8.24. Desarrolle el ejercicio 12. ¿Qué relación encuentra con el problema de n cuerpos de mecánica celeste?

# %% [markdown]
# ##### Solución

# %% [markdown]
# Sea $r = xi + yj +zk$ y sea $r =  \left\|{r}\right\|$. Si A y B son vectores constantes, show that:
#
# * (a)
#      \begin{equation}
#         A \cdot \nabla \left(\frac{1}{r}\right) = - \frac{A       \cdot r}{r^{3}}
#      \end{equation}
#
# Por teorema, tenemos que:
# \begin{equation}
# \
#  \nabla f(r) = \frac{df}{dr}\frac{r}{r}
# \end{equation}
# Entonces, tenemos que:
# \begin{equation}
#  \begin{split}
#    A \cdot \nabla \left(\frac{1}{r}\right) &
#    = A \cdot \nabla(r^{-1})\\&
#    = A \cdot \left(-r^{-2}\frac{r}{r}\right)\\&
#    = \frac{A \cdot r}{r^{3}}
#   \end{split}
# \end{equation}
#
#
# * (b)
#      \begin{equation}
#         B \cdot \nabla \left(A \cdot \nabla \left( \frac{1}{r}\right)\right) = - \frac{3A \cdot rB \cdot r}{r^{5}} - \frac{A \cdot B}{r^{3}}
#      \end{equation}
#
#
# Por teorema, tenemos que:
# \begin{equation}
#  \nabla (a \cdot r) = a
# \end{equation}
# Entonces, para cada vector $a$ constante, tenemos:
# \begin{equation}
#  \begin{split}
#    B \cdot \nabla \left(A \cdot r \left( \frac{1}{r}\right)\right) &
#    = B \cdot \nabla \left( \frac{A \cdot \nabla}{r^{3}}\right)\\&
#    = B \cdot ((-r^{3}) \nabla(A \cdot r) + \nabla(-r^{3})(A \cdot r))\\&
#    = B \cdot ((-r^{3})A \nabla(3r^{-5}r)(A \cdot r))\\&
#    = \frac{3(A \cdot r)(B \cdot r)}{r^{5}} - \frac{ A \cdot B}{r^{3}}
#   \end{split}
# \end{equation}
#
# R/ La estructura aquí demostrada es similar al problema de n cuerpos

# %% [markdown]
# $5.$ De Alonso-Finn, Física general, reproduzca en full detalle los ejemplos 27.1, 27.2, 27.4 y 27.5

# %% [markdown]
# #### Solución

# %% [markdown]
# ###### Ejemplo 27.1
#
# Fem inducida en un circuito plano compuesto por N vueltas, cada una de las áreas $S$ y perpenticularmente a un campo magnetico uniformente que oscila con una frecuencia $w$. Donde $B$ es igual al campo magnético.
#
# Sea $B = B_{0} \sin w t$ el campo magnetico. Entonces el flujo magnético a través de una vuelta del circuito es $\phi_{m}= S B= S B_{0}\sin w t$ y el flujo magnetico total a través de las $N$ vueltas es $\phi_{n}= NSB_{0}$. Aplicando la siguiente ecuación:
#
# \begin{equation}
# \oint \varepsilon \centerdot dl= - \frac{d}{dl} \int B \centerdot ds
# \end{equation}
#
# Obtenemos la Fem inducida:
#
# \begin{equation}
# Fem = -\frac{d \phi_{m}}{dt}=-NSB_{0}w\cos wt
# \end{equation}
#
# que indica que la Fem es oscilante y alterna con la misma frecuencia que el campo magnetico
#
# ###### Ejemplo 27.2
#
# Consideremos una región donde existe un campo magnético paralelo al eje $Z$ dependiente del tiempo y con simetría axial; esto es, la magnitud del campo varía únicamente con la distancia $r$ al eje $Z$. Determinar el campo eléctrico en cada punto del espacio.
#
# En la figura
#
# ![a.JPG](attachment:a.JPG)
#
# a, se muestra una vista lateral del campo magnético y en la figura
#
# ![b.JPG](attachment:b.JPG)
#
# b ,  una sección transversal. La simétria del problema sugiere que el campo eléctrico $\epsilon$ producido por el campo magnético variable en el tiempo debe depender sólo de la distancia $r$, y en cada punto debe ser perpendicular al campo magnético $B$ y al radio $r$. En otras palabras las líneas del campo eléctrico $\epsilon$ son círculos centrados en el eje $Z$. Tomando uno de tales círculos como trayectoria cerrada $l$ para la ecuación:
#
# \begin{equation}
# \oint \varepsilon \centerdot dl= - \frac{d}{dl} \int B \centerdot ds
# \end{equation}
#
# Tenemos:
#
# \begin{equation}
# Fem = \oint_{L} \epsilon \centerdot dl = \epsilon 2\pi r
# \end{equation}
#
# Por lo tanto usamos la siguiente ecuación:
#
# \begin{equation}
# Fem inducida= -\frac{d \phi_{m}}{dt}
# \end{equation}
#
# y obtenemos:
#
# \begin{equation}
# \epsilon ( 2 \pi r ) = -\frac{d \phi_{m}}{dt}
# \end{equation}
#
# El campo magnético promedio $B_{med}$ en una región que abarca una área $S$ es $B_{med}= \phi_{m}/S$ que da $\phi_{m}B_{med}S$. En nuestro caso, $S = \pi r^{2}$ de modo que $\phi_{m}= B_{med}(\pi r^{2})$, usando la ecuación:
#
# \begin{equation}
# \epsilon ( 2 \pi r ) = -\frac{d \phi_{m}}{dt}
# \end{equation}
#
# El campo eléctrico a una distancia $r$ del eje es:
#
# \begin{equation}
# \epsilon = -\frac{1}{2} \left ( \frac{d B_{med}}{dt} \right )
# \end{equation}
#
# ###### Ejemplo 27.4
#
# Autoinductancia de un circuito compuesto por dos láminas cilíndricas coaxiales con longitud $l$ y de radios $a$ y $b$, cada una con una corriente $I$ en sentidos opuestos.
#
# ![Cilindro.jpeg](attachment:Cilindro.jpeg)
#
# El espacio que hay entre los cilindros está lleno con una sustancia de permeabilidad $\mu$. Basados en los cálculos:
#
# \begin{equation}
# 2 \pi r B = \mu_{0} I  \space \space \space o \space \space \space  B = \frac{ \mu_{0}I }{2 \pi r} \space \space \space (r>a)
# \end{equation}
#
# El campo magnético para esta distribución de corriente es $B= \mu I /2 \pi r$ en la región comprendida entre los dos cilindros y $0$ en cualquier otro punto. Hemos sustituido $\mu_{0}$ en la ecución anterior por $\mu$, la permeabilidad del medio que llena el espacio entre dos cilindros de acuerdo con
#
# \begin{equation}
# \oint _{s} B \centerdot dS = 0
# \end{equation}
#
# Para obtener la autoinductancia debemos calcular el flujo magnetico a través de cualquier sección del conductor, como $PQRS$. Si dividimos esta sección con una longitud $l$ y un ancho $dr$ , el área de cada una será $l dr$. Como el campo magnético $B$ es perpendicular a $PQRS$ el flujo magnético. La autoinductancia de una porción del conductor, de longitud $l$, es
#
# \begin{equation}
# L = \frac {\phi I}{I} = \frac{\mu l}{2 \pi} \ln \frac{b}{a}
# \end{equation}
#
# ###### Ejemplo 27.5
#
# Corrientes de cierre y de apertura en un circuito con autoinductancia.
#
# Consideremos un circuito con resistencia $R$ y autoinductancia $L$. Cuando se aplica una fem $V_{0}$ al circuito colocando el conmutador en la posición $l$
#
#
# ![image.png](attachment:image.png)
#
#
# $V_{0}+V_{L}$, de manera que
#
# \begin{equation}
# R I + V_{L} = V_{0}  \space \space \space o \space \space \space  RI = V_{0}-L \frac{dl}{dt}
# \end{equation}
#
# La ecuación se puede escribir como:
#
# \begin{equation}
# RI-V_{0} = -L \frac{dl}{dt}
# \end{equation}
#
# o separando las variables I y t,
#
# \begin{equation}
# \frac{dl}{I- V_{0}/R} dt= -L \frac{R}{L} dt
# \end{equation}
#
# Tomando en cuenta que a $t=0$ la corriente es cero (I=0), podemos escribir la integral como
#
# \begin{equation}
# \int_{0}^{I} \frac{dI}{I-V_{0}/R} = - \frac{R}{L}\int_{0}^{t} dt
# \end{equation}
#
# al integral obtenemos
#
# \begin{equation}
# ln \left ( I- \frac{V_{0}}{RI} \right )- \ln \frac{-V_{0}}{R} = - \frac{R}{L}t
# \end{equation}

# %% [markdown]
# $6.$ De Alonso-Finn, Física general, reproduzca en full detalle la deducción del efecto Dopler (pg. 657) y el ejemplo 28.10

# %% [markdown]
# ##### Solución

# %% [markdown]
# ##### La deducción del efecto Doppler
#
# ![image.png](attachment:image.png)
#
# ###### Efecto Doppler:
# Cuando la fuente de una onda y el observador están en movimiento relativo con respecto al medio en que se propaga la onda, la frecuencia de las ondas observadas es diferente a la frecuencia de la fuente. Este fenomeno se conoce como efecto Doppler en honor a Christian J. Doppler, quien fue el primero en observarlo en ondas sonoras.
#
# Denotaremos con $v_{s}$ y $v_{0}$ a las velocidades de la fuente y del observador, con respecto al medio con el cual se propaga la onda, con velocidad de fase $v$. Entonces la relación entre la frecuencia $v$ y de la fuente de frecuencia $v´$ registrada por el observador cuando ambos se mueven en la dirección de propagación, esta dada por la expresión:
#
# \begin{equation}
# v´ = \frac{v- v_{0}}{v - v_{s}} v  \space \space \space \space \space \space \space \space (1)
# \end{equation}
#
# Cuando $v_{0}$ y $v_{s}$ son pequeñas en comparación con $v$, la expresión que relaciona a $v$ y a $v´$ se puede escribir de la forma:
#
# \begin{equation}
# v´ = \left (  1- \frac{v_{0s}}{v} \right ) v  \space \space \space \space \space \space \space (2)
# \end{equation}
#
# Donde $v_{0s} = v_{0}- v_{s}$ es la velocidad del observador con respecto a la fuente.
#
# ###### Deducción:
#
# Para obtener la relación entre la frecuencia $v$ de las ondas producidas por la fuente y la frecuencia $v´$ registrada por el observador, utilizamos el siguiente razonamiento. Por simplicidad supongamos que la fuente y el observador se mueven a lo largo de la misma linea y el observador $O$ está a la derecha de la fuente $S$. En cualquier caso la dirección positiva se toma como la del vector $\vec{SO}$.
#
# Supongamos que al tiempo $t=0$, cuando la fuente y el observador están separados por una distancia $\vec{SO} = l$ , la fuente emite una onda que llega al observador un tiempo $t$ más tarde. En ese tiempo, el observador se ha desplazado una distancia $v_{0}t$ y la distancia total recorrida por la onda es $l+v_{0}t$. Si $v$ es la velocidad de la propagación de la onda, está distancia es también $vt$. Entonces:
#
# \begin{equation}
# vt =  l + v_{0}t   \space \space \space o \space \space \space  t= \frac{l}{v_{0}}
# \end{equation}
#
# En el instante $t = \tau $ la fuente está en $S´$ y la ona emitida en ese instante llegará al observador en el tiempo $t´$, medido desde el mismo origen temporal del caso anterior. La distancia total recorrida por la onda desde el momento en el que es emitida en $S´$ hasta que es recibida por el observador es $\left ( l - v_{s} \tau \right ) + v_{0}t´$. El tiempo real de recorrido de la onda es $t´ - \tau$ y la distancia recorrida $v \left ( t´ - \tau \right )$. Por tanto:
#
# \begin{equation}
# v \left ( t´ - \tau \right ) = l- v_{s} \tau + v_{0} t´ \space \space \space o \space \space \space  t´= \frac{l+\left ( v-v_{s}  \right ) \tau}{v -v_{0}}
# \end{equation}
#
# El intervalo del tiempo, medido por el observador, entre dos ondas emitidas por la fuente en $S$ y en $S´$ es:
#
# \begin{equation}
# \tau´= t´-t = \frac {v-v_{s}}{v-v_{0}} \tau
# \end{equation}
#
# Ahora si $v$ es la frecuencia de la fuente, el número de ondas emitidas en el intervalo del tiempo $\tau$ es $vt$. Como las ondas son recibidas por el observador en el intervalo del tiempo $\tau´$ la frecuencia observada es:
#
# \begin{equation}
# v´= \frac{v\tau}{\tau´}  \space \space \space o \space \space \space  v´=\frac{v-v_{0}}{v-v_{s}}v
# \end{equation}
#
# que es la relación dada por la ecuación (1).
#
# Dividiendo numerador y denominador entre $v$, tenemos
#
# \begin{equation}
#  v´= \left (\frac{1-v_{0}/v}{1-v_{s}/v}  \right ) v = \left ( 1- \frac{v_{0}}{v} \right )\left ( 1 - \frac{v_{s}}{v}\right )^{-1} v
# \end{equation}
#
# Tomando los dos primeros términos de la expansión binomial, tenemos $ \left ( 1 - v_{s}/v \right ) \cong \left ( 1 + v_{s}/v \right )$, si $ v_{s}/v$ es mucho menor que uno. Entonces podemos escribir
#
# \begin{equation}
# v´ = \left ( 1- \frac{v_{0}}{v} \right )\left ( 1 - \frac{v_{s}}{v}\right ) v = \left ( 1- \frac{v_{0}}{v} + \frac{v_{s}}{v} - \frac{v_{0}v_{s}}{v^2} \right )v
# \end{equation}
#
# Cuando implicamos ambos párentesis debemos ser consistentes con nuestra aproximación y tomar en cuenta sólo los dos primeros términos. Entonces, despreciando el término $ v_{0}v_{s}/v^2 $, tenemos la frecuencia medida por el observador se reduce a
#
# \begin{equation}
# v´ = \left ( 1- \frac{v_{0} - v_{s}}{v} \right ) v = \left ( 1- \frac{v_{0s}}{v} \right )v
# \end{equation}
#
# Que es la ecuación aproximada (2).
#
# ###### Ejemplo 28.10
#
# La frecuencia del sonido producido por una campana de $500 Hz$. La velocidad de la fuente con respecto al aire en reposo es de $60 ms^{-1}$. Un observador se mueve a $30ms^{-1}$ sobre la misma línea que la fuente. Calcular la frecuencia del sonido medida por el observador. Considerar todos los casos posibles.
#
# Suponga que la velocidad del sonido es $340 ms^{-1}$ y la posicion relativa de la fuente y el observador es como esta figura:
#
# ![image.png](attachment:image.png)
#
# Primera caso: La fuente y el observador se mueven hacia la derecha. Como la velocidad de la fuente es mayor que la velocidad del observador $\left ( v_{s}>v_{0} \right )$, la fuente se acerca al observador. Ambas velocidades son positivas. Entonces, omitiendo algunas unidades:
#
# \begin{equation}
# v´ = \frac{v- v_{0}}{v - v_{s}} v=  \left ( \frac{340-30}{340-60}\right ) 500 Hz= 553 Hz
# \end{equation}
#
# Segundo caso: La fuente y el observador se mueven hacia la izquierda, entonces la fuente se aleja del observador y $v_{s}$ y $v_{0}$ son negativos, entonces:
#
# \begin{equation}
# v´ = \frac{v- v_{0}}{v - v_{s}} v=  \left ( \frac{340-(-30)}{340-(-60)}\right ) 500 Hz= 462 Hz
# \end{equation}
#
# Tercer caso: La fuente se mueve hacia la derecha y el observador hacia la izquierda, de modo que se acercan entre si. En este caso, la velocidad de la fuente es positiva y la velocidad del observador es negativa
#
# \begin{equation}
# v´ = \frac{v- v_{0}}{v - v_{s}} v=  \left ( \frac{340-(-30)}{340-60}\right ) 500 Hz= 660 Hz
# \end{equation}
#
# Cuarto caso: La fuente se mueve hacia la izquierda y el observador hacia la derecha, de manera que se alejan entre si. En este caso, la velocidad de la fuente es negativa y la velocidad del observador es positiva
#
# \begin{equation}
# v´ = \frac{v- v_{0}}{v - v_{s}} v=  \left ( \frac{340-30}{340-(-60)}\right ) 500 Hz= 387 Hz
# \end{equation}
#
# Considerando que el observador está parado en la izquierda, eso haría que nuestro campo de referencia cambiará:
#
# Primer caso: El observador y la fuente se mueven hacia la derecha
#
# \begin{equation}
# v´ = \frac{v- v_{0}}{v - v_{s}} v=  \left ( \frac{340-60}{340-30}\right ) 500 Hz= 451 Hz
# \end{equation}
#
# Segundo caso: Observador y fuente se dirigen hacia la izquierda
#
# \begin{equation}
# v´ = \frac{v- v_{0}}{v - v_{s}} v=  \left ( \frac{340-(-60)}{340-(-30)}\right ) 500 Hz= 540 Hz
# \end{equation}
#
# Tecer caso: El observador se mueve hacia la derecha y la fuente hacia la izquierda
#
# \begin{equation}
# v´ = \frac{v- v_{0}}{v - v_{s}} v=  \left ( \frac{340-(-60)}{340-30}\right ) 500 Hz= 645 Hz
# \end{equation}
#
# Cuarto caso: El observador se mueve hacia la izquierda y la fuente hacia la derecha
#
# \begin{equation}
# v´ = \frac{v- v_{0}}{v - v_{s}} v=  \left ( \frac{340-60}{340-(-30)}\right ) 500 Hz= 378 Hz
# \end{equation}

# %% [markdown]
# $7.$ Comente, física y matemáticamente el código que encontrará abajo, de tal manera que sea completamente claro, de que situación física se trata, que leyes se aplican, y que herramientas de python hacen posible el resultado que se muestra.

# %%
from __future__ import division, print_function
import numpy as np
import matplotlib.pyplot as plt


def elec_field(x, y, x_coords=[0], y_coords=[0], charges=[1]):
    Ex = np.zeros_like(x)
    Ey = np.zeros_like(x)
    for x0, y0, q in zip(x_coords, y_coords, charges):
        R = np.sqrt((x - x0)**2 + (y - y0)**2) + 1e-6
        Ex += q*(x - x0)/R**3
        Ey += q*(y - y0)/R**3
    return Ex, Ey


y, x = np.mgrid[-3:3:21j, -3:3:21j]
Ex, Ey = elec_field(x, y, x_coords=[-1, 1], y_coords=[0,0],
                    charges=[1, -1])
Emag = np.sqrt(Ex**2 + Ey**2)
dir_x = Ex/Emag
dir_y = Ey/Emag

plt.figure(figsize=(8, 6))
plt.subplot(221)
plt.quiver(x[::2, ::2], y[::2, ::2], dir_x[::2, ::2], dir_y[::2, ::2],
           np.log10(Emag[::2, ::2]), cmap="autumn", scale_units="inches",
           scale=5, width=0.015, pivot="mid")
plt.colorbar()
plt.axis("image")

plt.subplot(222)
plt.streamplot(x, y, Ex, Ey, color=np.log10(Emag),cmap="autumn")
plt.colorbar()
plt.axis("image")


plt.subplot(223)
plt.contourf(x, y, np.log10(Emag), cmap="autumn")
plt.colorbar()
plt.quiver(x[::2, ::2], y[::2, ::2], dir_x[::2, ::2], dir_y[::2, ::2],
           scale_units="inches", scale=5, width=0.010, pivot="mid")
plt.axis("image")


plt.subplot(224)
plt.contourf(x, y, np.log10(Emag), cmap="autumn")
plt.colorbar()
plt.streamplot(x, y, Ex/Emag, Ey/Emag, color="black")
plt.axis("image")

plt.savefig("vector_field.png", dpi=300)
plt.show()

# %% [markdown]
# #### Solución

# %% [markdown]
# Las herramientas de Python utilizadas son las librerías, matplotlib, numpy y future.
# $$$$
# Fisiciamente hablando, este codigo representa el campo electrico dado un punto $x, y$ teniendo en cuenta una distribucion de cargas.
# Matematicamente se tiene un campo vectorial $f: \mathbb{R}^2 \longrightarrow \mathbb{R}^2$ definido como
#
# $$f(x,y) = q\frac{\vec{r}}{R^3}$$
#
# Donde $q$ es una carga electrica, $r$ es un vector y $R^3$ es la distancia entre el punto dado y la carga electrica. En la funcion "elec_field" hay 5 parametros, elec_field(x, y, x_coords=[0], y_coords=[0], charges=[1]), los dos primeros, $x, y$ son las coordeadas de un punto e el plano y "x_coords=[0], y_coords=[0]" son arreglos donde se guardan las coordenadas en $x$ y $y$ respectivamente de donde se situa la carga, por ultimo, $charges=[1]$ representa la carga situada en el plano.
